# %%
import pandas as pd
import numpy as np
from pybaseball import statcast
from pybaseball import cache
cache.enable()
# Out:
# /Users/bryanbaker/.pyenv/versions/3.10.3/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(

# %%
pd.set_option('display.max_columns', 100)
merged = pd.read_csv('merged_fb.csv', index_col=0)
merged
# Out:
# /var/folders/2v/rhntcrz56677qkbl_ggqtpl40000gn/T/ipykernel_11822/3090169100.py:2: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged = pd.read_csv('merged_fb.csv', index_col=0)
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            SL  2015-07-12           86.2          -3.25           5.41
# 128          FF  2015-07-12           95.2          -3.11           5.35
# 281          FF  2015-07-12           94.9          -3.03           5.43
# 636          FF  2015-07-12           94.5          -3.28           5.18
# 742          FF  2015-07-12           94.8          -3.14           5.31
# ...         ...         ...            ...            ...            ...
# 3607         FF  2021-04-01           93.3          -1.33           6.00
# 1699         SL  2021-04-01           86.8           1.29           6.28
# 933          CH  2021-04-01           86.3          -2.16           6.27
# ...

# %%
df = pd.read_csv('fb_2022.csv', index_col=0)
df
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 2945         FF  2022-07-17           94.7          -0.89           7.03
# 2570         FF  2022-07-17           97.9           3.59           5.55
# 3041         FF  2022-07-17           97.8          -0.44           6.62
# 261          FF  2022-07-17           91.8          -0.80           6.02
# 262          SL  2022-07-17           78.0          -1.43           5.93
# ...         ...         ...            ...            ...            ...
# 79           SI  2022-03-17           91.7          -1.74           5.86
# 89           CH  2022-03-17           82.6          -1.93           5.83
# 21           SL  2022-03-17           84.9           2.67           5.57
# 196          SL  2022-03-17           83.3          -2.24           5.60
# 500         NaN  2022-03-17            NaN            NaN            NaN
#
#          player_name  batter  pitcher     events    description  spin_dir  \
# ...

# %%
pd.set_option('display.max_rows', 10000)

# %%
df[(df['launch_speed']>=90) & (df['launch_speed']<92)].events.value_counts(normalize=True)*100
# Out:
# field_out              91.453616
# sac_fly                 3.871439
# double                  2.629657
# home_run                0.657414
# single                  0.584368
# triple                  0.292184
# field_error             0.219138
# sac_fly_double_play     0.146092
# double_play             0.146092
# Name: events, dtype: float64

# %%
merged[(merged['launch_speed']>=90) & (merged['launch_speed']<92)].events.value_counts(normalize=True)*100
# Out:
# field_out              91.114542
# sac_fly                 3.972487
# double                  2.400337
# home_run                1.207187
# triple                  0.449186
# field_error             0.280741
# single                  0.266704
# double_play             0.238630
# sac_fly_double_play     0.056148
# force_out               0.014037
# Name: events, dtype: float64

# %%
df[df['launch_speed']<90].events.value_counts(normalize=True)*100
# Out:
# field_out              82.005176
# single                 11.851246
# sac_fly                 2.724424
# double                  2.601825
# double_play             0.340553
# field_error             0.231576
# triple                  0.108977
# force_out               0.095355
# home_run                0.027244
# sac_fly_double_play     0.013622
# Name: events, dtype: float64

# %%
merged[merged['launch_speed']<90].events.value_counts(normalize=True)*100
# Out:
# field_out              84.661386
# single                  9.237790
# sac_fly                 2.843204
# double                  2.268793
# double_play             0.375072
# field_error             0.222945
# triple                  0.175733
# force_out               0.104915
# home_run                0.068195
# sac_fly_double_play     0.041966
# Name: events, dtype: float64

# %%
df.groupby('launch_speed').events.value_counts()
# Out:
# launch_speed  events
# 51.4          double                  1
# 52.1          double                  1
# 54.8          double                  1
# 55.0          single                  1
# 56.1          field_out               1
# 56.9          single                  1
# 57.1          double                  1
# 57.9          double                  1
# 58.4          single                  1
# 59.2          single                  1
# 59.4          single                  1
# 59.5          field_out               1
# 60.2          single                  1
# 60.3          sac_fly                 1
# 60.6          field_out               3
#               single                  1
# 60.7          double                  1
#               field_out               1
#               single                  1
# 60.8          field_out               3
#               single                  2
# 61.4          field_out               1
# 61.5          field_out               2
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 if df.launch_speed < 85:
#       2     print('under 85')
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
