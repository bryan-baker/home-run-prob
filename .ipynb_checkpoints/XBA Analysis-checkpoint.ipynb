# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.offline as pyo
import datetime as dt
from pybaseball import statcast
from pybaseball import statcast_batter_exitvelo_barrels
from pybaseball import cache
cache.enable()
# Out:
# /Users/bryanbaker/.pyenv/versions/3.10.3/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning:
#
# urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!

# %%
df = statcast(start_dt='2021-01-01', end_dt='2021-12-30')
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# Skipping offseason dates
# 100%|█████████████████████████████████████████| 246/246 [02:02<00:00,  2.01it/s]

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 114          FF 2021-11-02           93.7           1.39           6.72
# 120          FF 2021-11-02           92.9           1.38           6.72
# 126          FF 2021-11-02           93.1           1.35           6.73
# 130          FF 2021-11-02           94.6           1.31           6.73
# 138          FF 2021-11-02           93.6           1.31            6.8
# ...         ...        ...            ...            ...            ...
# 1805       None 2021-03-15           <NA>           <NA>           <NA>
# 1875       None 2021-03-15           <NA>           <NA>           <NA>
# 2063       None 2021-03-15           <NA>           <NA>           <NA>
# 2269       None 2021-03-15           <NA>           <NA>           <NA>
# 2527       None 2021-03-15           <NA>           <NA>           <NA>
#
#         player_name  batter  pitcher     events    description  spin_dir  \
# ...

# %%
df = df[df['description']=='hit_into_play']

# %%
df = df.rename(columns={'estimated_ba_using_speedangle': 'xBA'})

# %%
df.dropna(subset='xBA')

# %%
plt.scatter(df.launch_speed, df.launch_angle, s=200, c=df.estimated_ba_using_speedangle	, cmap='Greens')
