# %%
import pandas as pd
import numpy as np
from pybaseball import statcast
from pybaseball import statcast_batter_exitvelo_barrels
from pybaseball import cache
cache.enable()

# %%
pd.set_option('display.max_columns', 100)
merged = pd.read_csv('merged_fb.csv', index_col=0)
merged
# Out:
# /var/folders/2v/rhntcrz56677qkbl_ggqtpl40000gn/T/ipykernel_43741/3090169100.py:2: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged = pd.read_csv('merged_fb.csv', index_col=0)
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            SL  2015-07-12           86.2          -3.25           5.41
# 128          FF  2015-07-12           95.2          -3.11           5.35
# 281          FF  2015-07-12           94.9          -3.03           5.43
# 636          FF  2015-07-12           94.5          -3.28           5.18
# 742          FF  2015-07-12           94.8          -3.14           5.31
# ...         ...         ...            ...            ...            ...
# 3607         FF  2021-04-01           93.3          -1.33           6.00
# 1699         SL  2021-04-01           86.8           1.29           6.28
# 933          CH  2021-04-01           86.3          -2.16           6.27
# ...

# %%
df = pd.read_csv('fb_2022.csv', index_col=0)
df
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 2945         FF  2022-07-17           94.7          -0.89           7.03
# 2570         FF  2022-07-17           97.9           3.59           5.55
# 3041         FF  2022-07-17           97.8          -0.44           6.62
# 261          FF  2022-07-17           91.8          -0.80           6.02
# 262          SL  2022-07-17           78.0          -1.43           5.93
# ...         ...         ...            ...            ...            ...
# 79           SI  2022-03-17           91.7          -1.74           5.86
# 89           CH  2022-03-17           82.6          -1.93           5.83
# 21           SL  2022-03-17           84.9           2.67           5.57
# 196          SL  2022-03-17           83.3          -2.24           5.60
# 500         NaN  2022-03-17            NaN            NaN            NaN
#
#          player_name  batter  pitcher     events    description  spin_dir  \
# ...

# %%
pd.set_option('display.max_rows', 10000)

# %%
df[(df['launch_speed']>=90) & (df['launch_speed']<92)].events.value_counts(normalize=True)*100
# Out:
# field_out              91.453616
# sac_fly                 3.871439
# double                  2.629657
# home_run                0.657414
# single                  0.584368
# triple                  0.292184
# field_error             0.219138
# sac_fly_double_play     0.146092
# double_play             0.146092
# Name: events, dtype: float64

# %%
merged[(merged['launch_speed']>=90) & (merged['launch_speed']<92)].events.value_counts(normalize=True)*100
# Out:
# field_out              91.114542
# sac_fly                 3.972487
# double                  2.400337
# home_run                1.207187
# triple                  0.449186
# field_error             0.280741
# single                  0.266704
# double_play             0.238630
# sac_fly_double_play     0.056148
# force_out               0.014037
# Name: events, dtype: float64

# %%
df[df['launch_speed']<90].events.value_counts(normalize=True)*100
# Out:
# field_out              82.005176
# single                 11.851246
# sac_fly                 2.724424
# double                  2.601825
# double_play             0.340553
# field_error             0.231576
# triple                  0.108977
# force_out               0.095355
# home_run                0.027244
# sac_fly_double_play     0.013622
# Name: events, dtype: float64

# %%
merged[merged['launch_speed']<90].events.value_counts(normalize=True)*100
# Out:
# field_out              84.661386
# single                  9.237790
# sac_fly                 2.843204
# double                  2.268793
# double_play             0.375072
# field_error             0.222945
# triple                  0.175733
# force_out               0.104915
# home_run                0.068195
# sac_fly_double_play     0.041966
# Name: events, dtype: float64

# %%
df.groupby('launch_speed').events.value_counts()
# Out:
# launch_speed  events
# 51.4          double                  1
# 52.1          double                  1
# 54.8          double                  1
# 55.0          single                  1
# 56.1          field_out               1
# 56.9          single                  1
# 57.1          double                  1
# 57.9          double                  1
# 58.4          single                  1
# 59.2          single                  1
# 59.4          single                  1
# 59.5          field_out               1
# 60.2          single                  1
# 60.3          sac_fly                 1
# 60.6          field_out               3
#               single                  1
# 60.7          double                  1
#               field_out               1
#               single                  1
# 60.8          field_out               3
#               single                  2
# 61.4          field_out               1
# 61.5          field_out               2
# ...

# %%
# df['ev_range'] = pd.cut(df['launch_speed'], bins=3)

# %%
df
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 2945         FF  2022-07-17           94.7          -0.89           7.03
# 2570         FF  2022-07-17           97.9           3.59           5.55
# 3041         FF  2022-07-17           97.8          -0.44           6.62
# 261          FF  2022-07-17           91.8          -0.80           6.02
# 262          SL  2022-07-17           78.0          -1.43           5.93
# ...         ...         ...            ...            ...            ...
# 79           SI  2022-03-17           91.7          -1.74           5.86
# 89           CH  2022-03-17           82.6          -1.93           5.83
# 21           SL  2022-03-17           84.9           2.67           5.57
# 196          SL  2022-03-17           83.3          -2.24           5.60
# 500         NaN  2022-03-17            NaN            NaN            NaN
#
#          player_name  batter  pitcher     events    description  spin_dir  \
# ...

# %%
barrels = statcast_batter_exitvelo_barrels(2022)

# %%
df = df.merge(barrels,left_on='batter', right_on='player_id')

# %%
df = df.rename(columns={' first_name':'first_name'})

# %%
df['batter_name']= df['first_name'] + ' ' + df['last_name']

# %%
df
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0             FF  2022-07-17           94.7          -0.89           7.03
# 1             SL  2022-07-12           81.2          -1.10           6.17
# 2             CU  2022-07-10           75.1           1.26           6.19
# 3             CH  2022-07-09           82.3           2.65           5.02
# 4             SL  2022-07-08           82.2           2.68           5.29
# ...          ...         ...            ...            ...            ...
# 15430        NaN  2022-03-30            NaN            NaN            NaN
# 15431         FF  2022-03-27           91.9           0.39           6.09
# 15432        NaN  2022-03-26            NaN            NaN            NaN
# 15433        NaN  2022-03-24            NaN            NaN            NaN
# 15434        NaN  2022-03-23            NaN            NaN            NaN
#
#              player_name  batter  pitcher       events    description  \
# ...

# %%
df.groupby('batter_name').events.value_counts()
# Out:
# batter_name             events
#  AJ Pollock             field_out              40
#                         home_run                6
#                         single                  3
#                         double                  2
#                         sac_fly                 1
#                         triple_play             1
#  Aaron Hicks            field_out              31
#                         home_run                6
#                         sac_fly                 3
#                         single                  3
#                         force_out               1
#                         triple                  1
#  Aaron Judge            field_out              47
#                         home_run               32
#                         double                  8
#                         single                  3
#                         sac_fly                 2
#  Abraham Toro           field_out              55
# ...

# %%
pd.set_option('display.max_columns', None)
new = df[(df['launch_speed']>=100) & (df['launch_speed']<=106) & (df['launch_angle']>=25)]

# %%
new.groupby('batter_name').events.value_counts()
# Out:
# batter_name             events
#  AJ Pollock             field_out               6
#                         home_run                4
#                         double                  1
#                         triple_play             1
#  Aaron Hicks            field_out               4
#                         home_run                4
#                         triple                  1
#  Aaron Judge            field_out              12
#                         home_run                7
#                         double                  2
#  Abraham Toro           field_out               3
#                         home_run                3
#                         triple                  1
#  Adam Duvall            field_out               7
#                         home_run                7
#                         double                  1
#  Adam Frazier           field_out               1
#  Adolis García          field_out               9
# ...

# %%
new.groupby('batter_name').agg({'events': ['count']})
# Out:
#                        events
#                         count
# batter_name
#  AJ Pollock                12
#  Aaron Hicks                9
#  Aaron Judge               21
#  Abraham Toro               7
#  Adam Duvall               15
#  Adam Frazier               1
#  Adolis García             16
#  Alec Bohm                  7
#  Aledmys Díaz               4
#  Alejandro Kirk             8
#  Alek Thomas                5
#  Alex Bregman               8
#  Alex Verdugo               2
#  Amed Rosario               8
#  Andrew Benintendi          9
#  Andrew McCutchen          11
#  Andrew Vaughn              9
#  Andrew Velazquez          10
#  Andrés Giménez            12
#  Anthony Rizzo             22
#  Anthony Santander         12
#  Austin Hays               12
#  Austin Nola                2
#  Austin Riley              18
#  Avisaíl García            10
#  Ben Gamel                  5
#  Bo Bichette               15
#  Bobby Dalbec               7
# ...

# %%
new.launch_speed.max()
# Out:
# 106.0

# %%
new.bb_type.value_counts()
# Out:
# fly_ball    2742
# Name: bb_type, dtype: int64
